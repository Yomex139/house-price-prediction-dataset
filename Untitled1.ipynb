# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import Series,DataFrame

# %% [markdown]
# # importing dataset

# %%
df = pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
df.describe().T
# Out:
#                 count           mean  ...        75%       max
# Id             1460.0     730.500000  ...    1095.25    1460.0
# MSSubClass     1460.0      56.897260  ...      70.00     190.0
# LotFrontage    1201.0      70.049958  ...      80.00     313.0
# LotArea        1460.0   10516.828082  ...   11601.50  215245.0
# OverallQual    1460.0       6.099315  ...       7.00      10.0
# OverallCond    1460.0       5.575342  ...       6.00       9.0
# YearBuilt      1460.0    1971.267808  ...    2000.00    2010.0
# YearRemodAdd   1460.0    1984.865753  ...    2004.00    2010.0
# MasVnrArea     1452.0     103.685262  ...     166.00    1600.0
# BsmtFinSF1     1460.0     443.639726  ...     712.25    5644.0
# BsmtFinSF2     1460.0      46.549315  ...       0.00    1474.0
# BsmtUnfSF      1460.0     567.240411  ...     808.00    2336.0
# TotalBsmtSF    1460.0    1057.429452  ...    1298.25    6110.0
# 1stFlrSF       1460.0    1162.626712  ...    1391.25    4692.0
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
for column,contents in df.items():
    if pd.api.types.is_numeric_dtype(contents):
        if pd.isna(contents).sum():
            df[column+'_is_missing'] = pd.isnull(contents)
            df[column] = contents.fillna(contents.mean())
            print(column)

# %%
for column,contents in df.items():
    if pd.api.types.is_string_dtype(contents):
        df[column+'_is_missing'] = pd.isnull(contents)
        df[column] = pd.Categorical(contents).codes +1

# %%
pd.api.types.is_categorical_dtype(df.PavedDrive)
# Out:
# False

# %%
df_copy = df.copy()
df_copy.sort_values(by='YrSold',
                    ascending=True,
                   inplace=True)
df_copy
# Out:
# 781     2006
# 1219    2006
# 281     2006
# 569     2006
# 1220    2006
#         ...
# 353     2010
# 1322    2010
# 162     2010
# 158     2010
# 1284    2010
# Name: YrSold, Length: 1460, dtype: int64

# %% [markdown]
# # modelling

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
RFR = RandomForestRegressor()
KNe = KNeighborsRegressor()

# %%
train_div = df_copy['YrSold'] != 2010
valid_div = df_copy['YrSold']  == 2010
X_train,Y_train = df_copy.drop('SalePrice',axis=1)[train_div],df_copy['SalePrice'][train_div]
X_valid,Y_valid = df_copy.drop('SalePrice',axis=1)[valid_div],df_copy['SalePrice'][valid_div]

# %%
RFR.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
RFR.predict(X_valid)
# Out:
# array([100568.11, 179327.3 , 195904.98, 236025.05, 200644.77, 110508.96,
#        208097.47, 145260.  , 150113.54, 397441.05, 190220.  , 139944.87,
#        165017.37, 128983.79, 145752.25, 199139.72, 239252.91,  80897.5 ,
#        212290.26, 137701.  , 143261.64, 258574.75, 323703.53, 116514.26,
#        264112.52, 134028.49, 247665.72, 199699.4 ,  84155.  , 140286.03,
#         93421.61, 102735.38, 176786.34, 164976.44, 117995.98, 303226.37,
#        109905.3 , 215700.02, 122181.76, 145840.  , 217960.45, 142937.  ,
#        218344.37, 125755.96,  97069.  , 296412.49,  98488.94, 115386.63,
#         89928.03, 142340.52, 135412.64, 228463.02, 130725.73, 140418.4 ,
#        129619.57, 113566.99, 142782.25,  93473.83,  96026.11, 165810.28,
#        255182.5 , 202530.97, 217878.73, 130239.06, 150173.  , 146999.5 ,
#        110234.7 , 146958.75, 270760.6 , 153449.02, 221447.2 , 137404.75,
#        141986.09, 127198.25, 362186.24, 120886.  , 170103.38, 207618.7 ,
# ...

# %%
df1 = pd.read_csv('test.csv')
df1
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 80 columns]

# %%
def Test(df1):
    for column,contents in df.items():
        if pd.api.types.is_numeric_dtype(contents):
            if pd.isna(contents).sum():
                df[column+'_is_missing'] = pd.isnull(contents)
                df[column] = contents.fillna(contents.mean())
                for column,contents in df.items():
                    if pd.api.types.is_string_dtype(contents):
                        df[column+'_is_missing'] = pd.isnull(contents)
                        df[column] = pd.Categorical(contents).codes +1            
    return df1

# %%
Test(df1)
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 80 columns]
